# %% [markdown]
# # I.Cài kaggle và cài đặt dữ liệu và giải nén vào thứ mục data:
# 1. cài đặt kaggle: pip install kaggle
# 2. tải dữ liệu từ link vào thư mục hiện hành /content (code: pwd)
# 3. tạo thư mục data trong thư mục hiện hành
# 4. Giải nén tất cả vào thư mục data

# %%
! pip install kaggle
# !curl -L -o dog-and-cat-detection.zip\
  https://www.kaggle.com/api/v1/datasets/download/andrewmvd/dog-and-cat-detection
! mkdir data
#sudo apt-get install unzip
# !unzip /content/dog-and-cat-detection.zip -d data
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: data/annotations/Cats_Test3132.xml
#   inflating: data/annotations/Cats_Test3133.xml
#   inflating: data/annotations/Cats_Test3134.xml
#   inflating: data/annotations/Cats_Test3135.xml
#   inflating: data/annotations/Cats_Test3136.xml
#   inflating: data/annotations/Cats_Test3137.xml
#   inflating: data/annotations/Cats_Test3138.xml
#   inflating: data/annotations/Cats_Test3139.xml
#   inflating: data/annotations/Cats_Test314.xml
#   inflating: data/annotations/Cats_Test3140.xml
#   inflating: data/annotations/Cats_Test3141.xml
#   inflating: data/annotations/Cats_Test3142.xml
#   inflating: data/annotations/Cats_Test3143.xml
#   inflating: data/annotations/Cats_Test3144.xml
#   inflating: data/annotations/Cats_Test3145.xml
#   inflating: data/annotations/Cats_Test3146.xml
#   inflating: data/annotations/Cats_Test3147.xml
#   inflating: data/annotations/Cats_Test3148.xml
# ...

# %% [markdown]
# # II. Tải model yolo v1 từ github.
# 1. Xóa data folder trong github vừa tải vì đó là dữ liệu mẫu để khái quát.
#     - Xóa từng file trong folder data : ! rm yolo-v1-tf2.0/data/*/*
#     - xóa thư mục trong data: ! rmdir yolo-v1-tf2.0/data/*
#     - xóa data folder: ! rmdir yolo-v1-tf2.0/data
# 2. Đưa tất cả file và folder trong github ra thư mục hiện hành /content

# %%
! git clone https://github.com/thanhhoai2k4/yolo-v1-tf2.0.git
! rm yolo-v1-tf2.0/data/*/*
! rmdir yolo-v1-tf2.0/data/*
! rmdir yolo-v1-tf2.0/data
! cp -r yolo-v1-tf2.0/. /content/
# Out:
# Cloning into 'yolo-v1-tf2.0'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 146 (delta 67), reused 114 (delta 44), pack-reused 0 (from 0)
# Receiving objects: 100% (146/146), 1.59 MiB | 1.19 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %% [markdown]
# # III. Huấn luyện model và save model

# %%
! python3 training.py
# Out:
# 2025-04-17 15:18:01.538867: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744903081.558459   22599 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744903081.564408   22599 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 15:18:01.586126: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
